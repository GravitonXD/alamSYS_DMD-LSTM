# %%
import pandas as pd

# %%
df = pd.read_csv('model_s5.csv', index_col=0)
df = df.sort_index()
df
# Out:
#             MSE      RMSE       MAE          MAPE
# AC     0.002358  0.048564  0.034138  6.109170e-03
# ALI    0.002554  0.050542  0.036451  1.596931e-02
# AP     0.001293  0.035959  0.025151  9.217251e-03
# BDO    0.001599  0.039993  0.027989  7.247630e-03
# BLOOM  0.018826  0.137206  0.069007  1.052898e+12
# FGEN   0.002241  0.047334  0.032651  1.197438e-02
# GLO    0.002111  0.045949  0.031491  4.676969e-03
# ICT    0.003347  0.057850  0.037312  3.005818e+11
# JGS    0.003309  0.057523  0.039921  2.009923e+11
# LTG    0.015670  0.125178  0.058580  3.583335e+12
# MEG    0.004309  0.065646  0.044220  1.393042e+11
# MER    0.003259  0.057085  0.037700  9.169602e-03
# MPI    0.002735  0.052296  0.033903  2.497115e-02
# PGOLD  0.001493  0.038646  0.028180  7.879349e-03
# PSEI   0.000018  0.004189  0.003283  1.507896e-03
# RLC    0.003384  0.058172  0.039777  6.922004e-02
# RRHI   0.001309  0.036185  0.026990  6.388692e-03
# SMC    0.001370  0.037018  0.023174  5.691306e-03
# ...

# %%
# Round off the values to 5 decimal places
df = df.round(5)
df
# Out:
#            MSE     RMSE      MAE          MAPE
# AC     0.00236  0.04856  0.03414  6.110000e-03
# ALI    0.00255  0.05054  0.03645  1.597000e-02
# AP     0.00129  0.03596  0.02515  9.220000e-03
# BDO    0.00160  0.03999  0.02799  7.250000e-03
# BLOOM  0.01883  0.13721  0.06901  1.052898e+12
# FGEN   0.00224  0.04733  0.03265  1.197000e-02
# GLO    0.00211  0.04595  0.03149  4.680000e-03
# ICT    0.00335  0.05785  0.03731  3.005818e+11
# JGS    0.00331  0.05752  0.03992  2.009923e+11
# LTG    0.01567  0.12518  0.05858  3.583335e+12
# MEG    0.00431  0.06565  0.04422  1.393042e+11
# MER    0.00326  0.05708  0.03770  9.170000e-03
# MPI    0.00273  0.05230  0.03390  2.497000e-02
# PGOLD  0.00149  0.03865  0.02818  7.880000e-03
# PSEI   0.00002  0.00419  0.00328  1.510000e-03
# RLC    0.00338  0.05817  0.03978  6.922000e-02
# RRHI   0.00131  0.03618  0.02699  6.390000e-03
# SMC    0.00137  0.03702  0.02317  5.690000e-03
# TEL    0.00178  0.04214  0.03002  4.240000e-03
# ...

# %%
df.describe()
# Out:
#              MSE       RMSE        MAE          MAPE
# count  20.000000  20.000000  20.000000  2.000000e+01
# mean    0.003797   0.054597   0.034868  2.638556e+11
# std     0.004733   0.029301   0.013204  8.177839e+11
# min     0.000020   0.004190   0.003280  1.510000e-03
# 25%     0.001573   0.039655   0.028133  6.320000e-03
# 50%     0.002455   0.049550   0.034020  1.059500e-02
# 75%     0.003320   0.057603   0.038220  3.482605e+10
# max     0.018830   0.137210   0.069010  3.583335e+12

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

# %%
# Plot the MSE distribution and add a normal distribution on top
plt.hist(df['MSE'], bins=5, density=True, alpha=0.6, color='g')
mu, std = norm.fit(df['MSE'])
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "MSE distribution. mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.show()

# %%
# Plot the RMSE distribution and add a normal distribution on top
plt.hist(df['RMSE'], bins=5, density=True, alpha=0.6, color='g')
mu, std = norm.fit(df['RMSE'])
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "RMSE distribution. mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.show()

# %%
# Plot the MAE distribution and add a normal distribution on top
plt.hist(df['MAE'], bins=5, density=True, alpha=0.6, color='g')
mu, std = norm.fit(df['MAE'])
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "MAE distribution. mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.show()

# %%
# Plot the MAPE distribution and add a normal distribution on top
plt.hist(df['MAPE'], bins=5, density=True, alpha=0.6, color='g')
mu, std = norm.fit(df['MAPE'])
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "MAPE distribution. mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.show()
