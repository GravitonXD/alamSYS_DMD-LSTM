# %%
import matplotlib.pyplot as plt

# %%
#MSE, RMSE, MAE, MAPE
win5 = [1.7547831110700054e-05,0.004189013142817775,0.003282715775307006,0.001507895828047589]
win10 = [4.085433653393971e-05,0.00639173971105987,0.004984381407170562,0.002288420978937786]
win15 = [3.912591469048572e-05,0.006255071117939885,0.004142081727067567,0.0019046016464762977]
win20 = [7.322582229059844e-05,0.00855720879087325,0.006455499639920296,0.0029648261136105067]
sizes = [5,10,15,20]

# %%
# Bar Graph for MSE across different window sizes
plt.bar([5,10,15,20], [win5[0],win10[0],win15[0],win20[0]], color='blue')
plt.title('MSE across different window sizes (DMD-LSTM)')
plt.xlabel('Window Size')
plt.ylabel('MSE')
plt.xticks([5,10,15,20])
# Add a bar on top showing the difference between the two (next bar - current bar)
plt.bar([5,10,15,20], [win10[0]-win5[0],win15[0]-win10[0],win20[0]-win15[0],0], bottom=[win5[0],win10[0],win15[0],win20[0]], color='red')
plt.ylim(0, 0.00008)
plt.show()

for i in range(4):
    diff = "{:.5f}".format([win10[0]-win5[0],win15[0]-win10[0],win20[0]-win15[0],0][i])
    try:
        print(f'Difference between window size {sizes[i]} and {sizes[i+1]} is {diff}')
    except:
        pass
# Out:
# Difference between window size 5 and 10 is 0.00002
# Difference between window size 10 and 15 is -0.00000
# Difference between window size 15 and 20 is 0.00003

# %%
# Bar Graph for RMSE across different window sizes
plt.bar([5,10,15,20], [win5[1],win10[1],win15[1],win20[1]], color='blue')
plt.title('RMSE across different window sizes (DMD-LSTM)')
plt.xlabel('Window Size')
plt.ylabel('RMSE')
plt.xticks([5,10,15,20])
# Add a bar on top showing the difference between the two (next bar - current bar)
plt.bar([5,10,15,20], [win10[1]-win5[1],win15[1]-win10[1],win20[1]-win15[1],0], bottom=[win5[1],win10[1],win15[1],win20[1]], color='red')
plt.ylim(0, 0.01)
plt.show()

for i in range(4):
    diff = "{:.5f}".format([win10[1]-win5[1],win15[1]-win10[1],win20[1]-win15[1],0][i])
    try:
        print(f'Difference between window size {sizes[i]} and {sizes[i+1]} is {diff}')
    except:
        pass
# Out:
# Difference between window size 5 and 10 is 0.00220
# Difference between window size 10 and 15 is -0.00014
# Difference between window size 15 and 20 is 0.00230

# %%
# Bar Graph for MAE across different window sizes
plt.bar([5,10,15,20], [win5[2],win10[2],win15[2],win20[2]], color='blue')
plt.title('MAE across different window sizes (DMD-LSTM)')
plt.xlabel('Window Size')
plt.ylabel('MAE')
plt.xticks([5,10,15,20])
# Add a bar on top showing the difference between the two (next bar - current bar)
plt.bar([5,10,15,20], [win10[2]-win5[2],win15[2]-win10[2],win20[2]-win15[2],0], bottom=[win5[2],win10[2],win15[2],win20[2]], color='red')
plt.ylim(0, 0.008)
plt.show()

for i in range(4):
    diff = "{:.5f}".format([win10[2]-win5[2],win15[2]-win10[2],win20[2]-win15[2],0][i])
    try:
        print(f'Difference between window size {sizes[i]} and {sizes[i+1]} is {diff}')
    except:
        pass
# Out:
# Difference between window size 5 and 10 is 0.00170
# Difference between window size 10 and 15 is -0.00084
# Difference between window size 15 and 20 is 0.00231

# %%
# Bar Graph for MAPE across different window sizes
plt.bar([5,10,15,20], [win5[3],win10[3],win15[3],win20[3]], color='blue')
plt.title('MAPE across different window sizes (DMD-LSTM)')
plt.xlabel('Window Size')
plt.ylabel('MAPE')
plt.xticks([5,10,15,20])
# Add a bar on top showing the difference between the two (next bar - current bar)
plt.bar([5,10,15,20], [win10[3]-win5[3],win15[3]-win10[3],win20[3]-win15[3],0], bottom=[win5[3],win10[3],win15[3],win20[3]], color='red')
plt.ylim(0, 0.0035)
plt.show()

for i in range(4):
    diff = "{:.5f}".format([win10[3]-win5[3],win15[3]-win10[3],win20[3]-win15[3],0][i])
    try:
        print(f'Difference between window size {sizes[i]} and {sizes[i+1]} is {diff}')
    except:
        pass
# Out:
# Difference between window size 5 and 10 is 0.00078
# Difference between window size 10 and 15 is -0.00038
# Difference between window size 15 and 20 is 0.00106
