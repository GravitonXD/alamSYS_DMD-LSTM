# %%
import matplotlib.pyplot as plt

# %%
#MSE, RMSE, MAE, MAPE
win5 = [0.07615895487932436,0.27596911943064273,0.275949626259796,0.12659175356184194]
win10 = [9.232829705334228e-05,0.009608761473433623,0.008494095263759951,0.0038998382619416603]
win15 = [0.017520964135483975,0.13236677882113765,0.13221706472713188,0.06066009164259066]
win20 = [0.004074235411641981,0.06382973767486422,0.06342811204197056,0.029093785646223835]
sizes = [5, 10, 15, 20]

# %%
# Bar Graph for MSE across different window sizes
plt.bar([5,10,15,20], [win5[0],win10[0],win15[0],win20[0]], color='blue')
plt.title('MSE across different window sizes (Baseline LSTM)')
plt.xlabel('Window Size')
plt.ylabel('MSE')
plt.xticks([5,10,15,20])
# Add a bar on top showing the difference between the two (next bar - current bar)
plt.bar([5,10,15,20], [win10[0]-win5[0],win15[0]-win10[0],win20[0]-win15[0],0], bottom=[win5[0],win10[0],win15[0],win20[0]], color='red')
plt.ylim(0, 0.08)
plt.show()

for i in range(4):
    diff = "{:.5f}".format([win10[0]-win5[0],win15[0]-win10[0],win20[0]-win15[0],0][i])
    try:
        print(f'Difference between window size {sizes[i]} and {sizes[i+1]} is {diff}')
    except:
        pass
# Out:
# Difference between window size 5 and 10 is -0.07607
# Difference between window size 10 and 15 is 0.01743
# Difference between window size 15 and 20 is -0.01345

# %%
# Bar Graph for RMSE across different window sizes
plt.bar([5,10,15,20], [win5[1],win10[1],win15[1],win20[1]], color='blue')
plt.title('RMSE across different window sizes (Baseline LSTM)')
plt.xlabel('Window Size')
plt.ylabel('RMSE')
plt.xticks([5,10,15,20])
# Add a bar on top showing the difference between the two (next bar - current bar)
plt.bar([5,10,15,20], [win10[1]-win5[1],win15[1]-win10[1],win20[1]-win15[1],0], bottom=[win5[1],win10[1],win15[1],win20[1]], color='red')
plt.ylim(0, 0.3)
plt.show()

for i in range(4):
    diff = "{:.5f}".format([win10[1]-win5[1],win15[1]-win10[1],win20[1]-win15[1],0][i])
    try:
        print(f'Difference between window size {sizes[i]} and {sizes[i+1]} is {diff}')
    except:
        pass
# Out:
# Difference between window size 5 and 10 is -0.26636
# Difference between window size 10 and 15 is 0.12276
# Difference between window size 15 and 20 is -0.06854

# %%
# Bar Graph for MAE across different window sizes
plt.bar([5,10,15,20], [win5[2],win10[2],win15[2],win20[2]], color='blue')
plt.title('MAE across different window sizes (Baseline LSTM)')
plt.xlabel('Window Size')
plt.ylabel('MAE')
plt.xticks([5,10,15,20])
# Add a bar on top showing the difference between the two (next bar - current bar)
plt.bar([5,10,15,20], [win10[2]-win5[2],win15[2]-win10[2],win20[2]-win15[2],0], bottom=[win5[2],win10[2],win15[2],win20[2]], color='red')
plt.ylim(0, 0.3)
plt.show()

for i in range(4):
    diff = "{:.5f}".format([win10[2]-win5[2],win15[2]-win10[2],win20[2]-win15[2],0][i])
    try:
        print(f'Difference between window size {sizes[i]} and {sizes[i+1]} is {diff}')
    except:
        pass
# Out:
# Difference between window size 5 and 10 is -0.26746
# Difference between window size 10 and 15 is 0.12372
# Difference between window size 15 and 20 is -0.06879

# %%
# Bar Graph for MAPE across different window sizes
plt.bar([5,10,15,20], [win5[3],win10[3],win15[3],win20[3]], color='blue')
plt.title('MAPE across different window sizes (Baseline LSTM)')
plt.xlabel('Window Size')
plt.ylabel('MAPE')
plt.xticks([5,10,15,20])
# Add a bar on top showing the difference between the two (next bar - current bar)
plt.bar([5,10,15,20], [win10[3]-win5[3],win15[3]-win10[3],win20[3]-win15[3],0], bottom=[win5[3],win10[3],win15[3],win20[3]], color='red')
plt.ylim(0, 0.15)
plt.show()

for i in range(4):
    diff = "{:.5f}".format([win10[3]-win5[3],win15[3]-win10[3],win20[3]-win15[3],0][i])
    try:
        print(f'Difference between window size {sizes[i]} and {sizes[i+1]} is {diff}')
    except:
        pass
# Out:
# Difference between window size 5 and 10 is -0.12269
# Difference between window size 10 and 15 is 0.05676
# Difference between window size 15 and 20 is -0.03157
